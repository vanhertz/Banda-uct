# %% [markdown]
# Mantenimiento preventivo en "Kushu-enterprise S.A."
# El presente análisis utiliza un enfoque de aprendizaje no supervisado (K-Means) en el
# contexto de la Industria 4.0. El objetivo es analizar los datos de sensores de 1,500 mo-
# tores industriales para automatizar la detección de anomalías y segmentar la maquinaria
# según su estado de salud operativo, permitiendo al equipo de ingeniería priorizar las tar-
# eas de mantenimiento antes de que ocurra una falla catastrófica. Donde en una planta de
# manufactura moderna, el mantenimiento correctivo (reparar cuando ya se rompió) genera
# pérdidas millonarias por paradas de producción imprevistas.
# En base a los datos recopilados de los sensores de motores industriales se pide realizar:
# 1. A partir del dataset entregado, generar la matriz de característica X1 considerando
# todas las variables.
# 2. Usando el algoritmo K-Means, aplicar el método del codo para determinar la can-
# tidad óptima de clusters.
# 3. Para la cantidad óptima de clústers determinados, calcular el diagrama de silueta y
# describir el resultado.
# 4. Mostrar dos muestras de datos de cada cluster que se determinó.
# 5. De acuerdo a la muestra de datos obtenida, caracterice cada uno de los clusters
# determinados.

# %%
import pandas as pd
import numpy as np
import openpyxl 

datos = pd.read_excel(r'C:\Users\Estudiante\Downloads\dataset_Ayudantia5_monitoreo_industrial.csv', header=0)
datos

# %%
from matplotlib import cm
from sklearn.metrics import silhouette_samples

km = KMeans(n_clusters=3, init='k-means++',n_init=10, max_iter=300,tol=1e-04,random_state=0)
y_km = km.fit_predict(X)

cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
    color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper), c_silhouette_vals, height=1.0, 
             edgecolor='none', color=color)

    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)
    
silhouette_avg = np.mean(silhouette_vals)
plt.axvline(silhouette_avg, color="red", linestyle="--") 

plt.yticks(yticks, cluster_labels + 1)
plt.ylabel('Cluster')
plt.xlabel('Silhouette coefficient')

plt.tight_layout()
plt.show()
